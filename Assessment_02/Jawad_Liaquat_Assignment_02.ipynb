# %%
# Task-1
print("Hello, everyone! I am learning Python. 😄")
# Out:
# Hello, everyone! I am learning Python. 😄

# %%
#Task-2
name= ('jawad')
AGE= ('36')
animal= ('cat')
print("My name is:",name)
print("MY age is:",AGE)
print("My favoraite animal is:",animal)
# Out:
# My name is: jawad
# MY age is: 36
# My favoraite animal is: cat

# %%
#Task-3
print(f'my name is {name} and my age is {AGE} and my personal is {animal}')

#Task-4
favorite_movie = "toy story"
BIRTH_YEAR = 1988
price_of_snake = 10.5
print("My favorite movie is:",favorite_movie)
print("Birth year is:",BIRTH_YEAR)
print("price is:",price_of_snake)
# Out:
# my name is jawad and my age is 36 and my personal is cat
# My favorite movie is: toy story
# Birth year is: 1988
# price is: 10.5

# %%
#Task-5
hobby = "Reading Books"
print("My favorite Hobby is:",hobby)
# Out:
# My favorite Hobby is: Reading Books

# %%
#Task-6
A = 10
B = 20
C = A+B
print("A=",A)
print("B=",B)
print("C=",C)
print("C=",C , "(A and B are combined)")
# Out:
# A= 10
# B= 20
# C= 30
# C= 30 (A and B are combined)
