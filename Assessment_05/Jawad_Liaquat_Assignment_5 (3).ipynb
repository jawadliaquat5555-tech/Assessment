# %%
#Task-1
full_name = input("Please enter your full name: ")

# Print a greeting message
print(f"Hello, {full_name}! Welcome to the Python assignment.")
# Out:
# Please enter your full name:  jawad
# Hello, jawad! Welcome to the Python assignment.

# %%
#Task-2
name = input("Enter your name: ")
print("Uppercase:", name.upper())
print("Lowercase:", name.lower())
print("Length:", len(name))
print("Hyphenated:", name.replace(" ", "-"))
trimmed_name = name.strip()
print("Trimmed:", trimmed_name)
# Out:
# Enter your name:  jawad liaquat
# Uppercase: JAWAD LIAQUAT
# Lowercase: jawad liaquat
# Length: 13
# Hyphenated: jawad-liaquat
# Trimmed: jawad liaquat
