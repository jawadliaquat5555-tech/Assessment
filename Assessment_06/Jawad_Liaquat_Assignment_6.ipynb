# %%
money = 50
item_price = 15
tax_rate = 0.03

# Calculate tax
tax = item_price * tax_rate

# Total cost including tax
total_cost = item_price + tax

# Remaining money
remaining_money = money - total_cost

# Print with $ symbol and 2 decimal places
print("Remaining money: ${:.2f}".format(remaining_money))
# Out:
# Remaining money: 34.55

# %%
days = int(input("Enter number of days until your birthday: "))
weeks = days // 7 
print("Approximate weeks until your birthday:", weeks)
# Out:
# Enter number of days until your birthday:  17
# Approximate weeks until your birthday: 2

# %%
Grade = int(input("Enter your numeric grade (0-100): "))
if Grade >= 90 and Grade <= 100:
    print("Letter Grade: A")
elif Grade >= 80:
    print("Letter Grade: B")
elif Grade >= 70:
    print("Letter Grade: C")
elif Grade >= 60:
    print("Letter Grade: D")
else:
    print("Letter Grade: F")
# Out:
# Enter your numeric grade (0-100):  50
# Letter Grade: F
